# %% [markdown]
# 📋 Classwork: Day 1
#
# - Ask the user for their birth year. Calculate and print their age.
#
# - Write a function that checks if a number is even or odd.
#
# - Create a list of all numbers divisible by 3 between 1 and 50 using list comprehension.
#
# - Write a function that takes a name and prints Hello, <name>!.
#
# - Use a while loop to print numbers from 1 to 5.

# %% [markdown]
# # Ask the user for their birth year. Calculate and print their age.
# #age = 2024 - int(input("Enter your birth year: "))
# #print(f"You are {age} years old.")

# %% [markdown]
# #Write a function that checks if a number is even or odd.
# #def check_even_odd(num):
#     #if num % 2 == 0:
#         return "Even"
#     else:
#         return "Odd"

# %% [markdown]
# Classwork: Day 4
#
# - Load the Titanic dataset and filter rows where Fare > 50. Sort by Age.
#
# - Create a new column FarePerPerson by dividing Fare by the number of parents/children (Parch + 1).
#
# - Group the data by Sex and show the average age and survival rate.
#
# - Merge two DataFrames: one with names and IDs, another with ages and IDs.
#
# - Plot a histogram of the Age column and a count plot of the Pclass.

# %%
# Load the Titanic dataset and filter rows where Fare > 50. Sort by Age.
import pandas as pd
df = pd.read_csv('tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Load the Titanic dataset and filter rows where Fare > 50. Sort by Age.
df[df['Fare'] > 50].sort_values(by='Age')
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 196         1088         0       1  Spedden, Master. Robert Douglas    male
# 64           956         0       1      Ryerson, Master. John Borie    male
# 230         1122         0       2      Sweet, Mr. George Frederick    male
# 360         1252         0       3      Sage, Master. William Henry    male
# 212         1104         0       2        Deacon, Mr. Percy William    male
# ..           ...       ...     ...                              ...     ...
# 39           931         0       3                    Hee, Mr. Ling    male
# 146         1038         0       1      Hilliard, Mr. Herbert Henry    male
# 188         1080         1       3                  Sage, Miss. Ada  female
# 342         1234         0       3            Sage, Mr. John George    male
# 365         1257         1       3   Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
#Create a new column FarePerPerson by dividing Fare by the number of parents/children (Parch + 1).
df['FarePerPerson'] = df['Fare'] / (df['Parch'] + 1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Group the data by Sex and show the average age and survival rate.
df.groupby('Age')['Survived'].mean()
# Out:
# Age
# 0.17     1.000000
# 0.33     0.000000
# 0.75     0.000000
# 0.83     0.000000
# 0.92     1.000000
#            ...
# 62.00    0.000000
# 63.00    0.500000
# 64.00    0.666667
# 67.00    0.000000
# 76.00    1.000000
# Name: Survived, Length: 79, dtype: float64

# %% [markdown]
# perfom joins using  powerbi customer sales table
#
# create visualizasions

# %%
import pandas as pd

# %% [markdown]
# # Probability and combinatorics

# %%
import math

# %%
# choose 2 fruits from 4
# define the total number of fruits (n) and the number of fruits to choose (r)
n = 4 # total of number of fruits
r = 2 # number of fruits to choose
# calculate the combination number
combination = math.comb(n, r)
print(f"The number of ways to choose {r} fruits from {n} fruits is: {combination}")
# Out:
# The number of ways to choose 2 fruits from 4 fruits is: 6
