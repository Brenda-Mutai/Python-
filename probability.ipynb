# %%
import pandas as pd

# %%
#reading a dataset
data=pd.read_csv(r'weight-height.csv')
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
import math

# %%
n=int(input(
   " Enter your experiments here:"
))
k=int(input(
    "Enter your desired value here:"
))
p=float(input(
    "Enter your probability here:"
))
math.comb(n,k)*(p**k)*(1-p)**(n-k)
# Out:
# 0.057375

# %%
n=int(input(
    'Enter your experiments here:'
))
k=int(input(
    'Enter your desired value here:'
))
p=float(input(
    'Enter your probability here:'
))
#formular
math.comb(n,k)*((p**k)*((1-p))**(n-k))
# Out:
# 0.3125

# %% [markdown]
# ## **Z-Score**
# * calculating probability occuring within a given normal distribution

# %%
#calculating z-score
x=70
mu=50
sd=10

z=(x-mu)/sd
z
# Out:
# 2.0

# %%
mean_IQ=100
s_d=15
x_IQ=120
z_IQ=(x_IQ-mean_IQ)/s_d
z_IQ
# Out:
# 1.3333333333333333

# %%
import numpy as np
import seaborn as sns
mean1, sd1 = 5, 3 # dist 1 
mean2, sd2 = 10, 2 # dist 2 
d1 = np.random.normal(mean1, sd1, 1000)
d2 = np.random.normal(mean2, sd2, 1000)
sns.distplot(d1);
sns.distplot(d2);
# Out:
# C:\Users\BRENDA MUTAI\AppData\Local\Temp\ipykernel_16784\526047934.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d1);
# C:\Users\BRENDA MUTAI\AppData\Local\Temp\ipykernel_16784\526047934.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d2);

# %%
# Stardardizing and visualizing distributions

sns.distplot([(x - d1.mean())/d1.std() for x in d1]);
sns.distplot([(x - d2.mean())/d2.std() for x in d2]);
# Out:
# C:\Users\BRENDA MUTAI\AppData\Local\Temp\ipykernel_16784\4206954641.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([(x - d1.mean())/d1.std() for x in d1]);
# C:\Users\BRENDA MUTAI\AppData\Local\Temp\ipykernel_16784\4206954641.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([(x - d2.mean())/d2.std() for x in d2]);

# %% [markdown]
# * predict the people who are more likely to survive and the ones not likely to survive
# * using the titanic data
